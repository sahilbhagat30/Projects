# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bank_churn_df = pd.read_csv("Bank Customer Churn Data/Prepared Data/cleaned_bank_churn_df.csv",
                            encoding="ISO-8859-1",
                            low_memory=False)
bank_churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Balance          10000 non-null  float64
#  3   NumOfProducts    10000 non-null  int64
#  4   HasCrCard        10000 non-null  object
#  5   Tenure           10000 non-null  int64
#  6   IsActiveMember   10000 non-null  object
#  7   Exited           10000 non-null  int64
#  8   Surname          10000 non-null  object
#  9   CreditScore      10000 non-null  int64
#  10  Geography        10000 non-null  object
#  11  Gender           10000 non-null  object
#  12  Age              10000 non-null  float64
#  13  EstimatedSalary  10000 non-null  float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 1.1+ MB

# %%
bank_churn_df = bank_churn_df.drop(["Unnamed: 0"], axis = 1)

# %%
bank_churn_df["Exited"].value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='Exited'>

# %%
sns.barplot(data=bank_churn_df,x = "Geography",y = "Exited")
# Out:
# <Axes: xlabel='Geography', ylabel='Exited'>

# %%
for col in bank_churn_df.drop("Surname", axis=1).select_dtypes("object"):
    plt.figure(figsize=(8, 4))
    sns.barplot(data=bank_churn_df, x=col, y="Exited")
    plt.title(f'Relationship between {col} and Exited')
    plt.xlabel(col)
    plt.ylabel("Exited")
    plt.show()

# %%
for col in bank_churn_df.drop(["CustomerId","Exited"], axis=1).select_dtypes("number"):
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=bank_churn_df, y=col, hue="Exited")
    plt.title(f'Relationship between {col} and Exited')
    plt.xlabel(col)
    plt.ylabel("Exited")
    plt.show()

# %%
for col in bank_churn_df.drop(["CustomerId","Exited"], axis=1).select_dtypes("number"):
    plt.figure(figsize=(8, 4))
    sns.histplot(data=bank_churn_df, x=col, hue="Exited",kde=True)
    plt.title(f'Relationship between {col} and Exited')
    plt.xlabel(col)
    plt.ylabel("Exited")
    plt.show()

# %%
for col in bank_churn_df.drop("Surname", axis=1).select_dtypes("object"):
    plt.figure(figsize=(8, 4))
    sns.barplot(data=bank_churn_df, x=col, y="Exited")
    plt.title(f'Relationship between {col} and Exited')
    plt.xlabel(col)
    plt.ylabel("Exited")
    plt.show()

# %%
sns.pairplot(bank_churn_df)

# %%
sns.heatmap(bank_churn_df.corr(numeric_only=True), vmin=-1, vmax=1, cmap="coolwarm" )
# Out:
# <Axes: >

# %%
bank_churn_df.to_csv("Bank Customer Churn Data/Prepared Data/obj4_bank_churn_df.csv")
bank_churn_df.describe()
# Out:
#          CustomerId        Balance  NumOfProducts        Tenure        Exited  \
# count  1.000000e+04   10000.000000   10000.000000  10000.000000  10000.000000
# mean   1.569094e+07   76485.889288       1.530200      5.012800      0.203700
# std    7.193619e+04   62397.405202       0.581654      2.892174      0.402769
# min    1.556570e+07       0.000000       1.000000      0.000000      0.000000
# 25%    1.562853e+07       0.000000       1.000000      3.000000      0.000000
# 50%    1.569074e+07   97198.540000       1.000000      5.000000      0.000000
# 75%    1.575323e+07  127644.240000       2.000000      7.000000      0.000000
# max    1.581569e+07  250898.090000       4.000000     10.000000      1.000000
#
#         CreditScore           Age  EstimatedSalary
# count  10000.000000  10000.000000     10000.000000
# mean     650.528800     38.921500    100092.252506
# std       96.653299     10.487552     57510.146401
# min      350.000000     18.000000        11.580000
# ...
